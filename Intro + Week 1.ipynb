# %% [markdown]
# <a href="https://colab.research.google.com/github/favouroo/Python-Basics-Data-Science/blob/Python-for-Data-Science/Intro%20%2B%20Week%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Python for Data Science
# ### To write a text, click on text botton that you see beside "+ Code". Use hashtags to make it a header.

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# #My First Notebook Here
#
# **First Notebook** <br>*First Notebook*
#
# ## The Zen of python
# by Tim Peters
#
# The zen of python are a set of rules. Read up [here](https://en.wikipedia.org/wiki/Zen_of_Python).

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# #Week 1
# ##Variables

# %%
username = "John"
print (username)
age = 20
print(age)
# Out:
# John
# 20

# %%
_2name= "Joy"
print(_2name)
# Out:
# Joy

# %%
first_name = "Jane" #this is snake case
FirstName = "Doe"

# %% [markdown]
# ##Basic Operators in Pyhton

# %%
x = 5
y= 2
print (x+y) #addition
print (x-y) #subtraction
c = x* y
print (c) #multiplication
print (x/y) #normal division
print (x//y) #floor division
print (x**y) #power
print (x%y) #modulo
# Out:
# 7
# 3
# 10
# 2.5
# 2
# 25
# 1

# %%
m = 15
n= 4
print(m/n)
print(m//n)
print(m%n)
# Out:
# 3.75
# 3
# 3

# %%
x == y #eqial to in python
x != y #not equal to each other
# Out:
# True

# %%
y>x
# Out:
# False

# %%
x>y
# Out:
# True

# %%
x>=2
# Out:
# True

# %%
#updating values
x = x+2
x += 2
print(x)
# Out:
# 9

# %%
m -= 2
print (m)
# Out:
# 13

# %% [markdown]
# ## **Data Types**
# ### Type Function
# To check data type of variable

# %%
number = 10 #integer
texts = "10" #strings
decimal = 3.4

print(type (texts))
print (type(number))
print(type (decimal))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
#boolean
print (True)
# Out:
# True

# %%
x = 10
y = 2
check = x>y
type(check)
# Out:
# bool

# %% [markdown]
# True is 1
#
#
# False is 0

# %%
True + False
# Out:
# 1

# %%
True + True
# Out:
# 2

# %%
False +False
# Out:
# 0

# %% [markdown]
# ###**Type Casting**

# %%
number = 10
float (number)
# Out:
# 10.0

# %%
float_num = float (number)
print(float_num)
# Out:
# 10.0

# %% [markdown]
# ###String Methods

# %%
name = "James"
name.upper()
# Out:
# 'JAMES'

# %%
name.lower()
# Out:
# 'james'

# %%
name_upper = name.upper()
print (name_upper)
# Out:
# JAMES

# %%
print(name_upper.title())
# Out:
# James

# %%
greeting = "Hxllo"
cleaned_greeting = greeting.replace("x", "e")
print(cleaned_greeting)
len(greeting)
# Out:
# Hello
# 5

# %%
full_name = " Favour Oluchukwu Okolie  "
len(full_name)
# Out:
# 26

# %%
full_name = " Favour Oluchukwu Okolie  "
stripped_full_name = full_name.strip()
len(stripped_full_name)
# Out:
# 23

# %%
cleaned_greeting.find("l")
# Out:
# 2

# %% [markdown]
# ###String Formatting

# %%
first_name = "Esther Favour"
last_name = "CHRIST"
age = 25
introduction = f"My name is {first_name} {last_name}. I am {age} years old." #Use this instead of retyping
print (introduction)
# Out:
# My name is Esther Favour CHRIST. I am 25 years old.

# %% [markdown]
# ###Slicing Strings

# %%
ubulu = "Blessing"
print(len(ubulu))
print(ubulu[0:5])
# Out:
# 8
# Bless

# %%
name = "Oluchukwu"
c_name= name.upper()
c_taitul = name.title()
print(c_name)
print(len(name))
print(name[0:3]) #extract the first 3 characters in the string
print(name[0:9:2])
print(c_name[3:9])
# Out:
# OLUCHUKWU
# 9
# Olu
# Ouhku
# CHUKWU

# %%
name = "Oluchukwu"
first_letter = name[-9]
last_letter = name[-1]
outcome = f"The first letter in the variable {name} is {first_letter} while the last letter is {last_letter}."
#negative indexing
print(name)
print(name[-4])
print(name[-4:])
print((name[5:]).title())
print(name[-9:-3])
print(name[-9:-3:2])
print(name[-9:-3:3])
print(name[-9:-1:3])
print(outcome)
# Out:
# Oluchukwu
# u
# ukwu
# Ukwu
# Oluchu
# Ouh
# Oc
# Ock
# The first letter in the variable Oluchukwu is O while the last letter is u.

# %% [markdown]
# ##**Data Structures**
# ###List

# %%
number = 10
#to create a list of numbers

num_list = [10, 20, 30, 40, 50, 60, -1, 0, 1000]
print(num_list)
print(type(num_list))

varying_list = [1,3.14,"Hello", True]
list_type = type(varying_list)
print(f"The data structure used here is {list_type}.\n")

print(num_list[-1])
print(num_list[0])
print(num_list[-3:])
# Out:
# [10, 20, 30, 40, 50, 60, -1, 0, 1000]
# <class 'list'>
# The data structure used here is <class 'list'>.
#
# 1000
# 10
# [-1, 0, 1000]

# %%
#to modify lists
nothing = [] #useful when you want to append later
print(nothing)
nothing.append(100)
nothing.append(150)
nothing.append(250)
nothing.append(150)
nothing.append(200)
nothing.append(-800)
print(nothing)
print()
#to insert
nothing.insert(3,145)
print(nothing)
print()
#to delete using the del keyword
del (nothing[-4:-2])
print(nothing)
#using the pop method
nothing.pop()
print(nothing)
#using the remove method
nothing.remove (250)
print(nothing)
# Out:
# []
# [100, 150, 250, 150, 200, -800]
#
# [100, 150, 250, 145, 150, 200, -800]
#
# [100, 150, 250, 200, -800]
# [100, 150, 250, 200]
# [100, 150, 200]
